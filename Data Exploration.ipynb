# %%
import pandas as pd

# %%
"""
Input: 
    Text file containing all the generated fake reviews from GPT2 fine tuned model
Output:
    Saves a 'fake_reviews.csv' in the current directory that labels every review as fake
    
Fake reviews are filtered to remove \n symbol and the GTP2 model 
included some lines containing only equal signs which are also removed.
"""
def create_df_from_txt(path):
    
    review_list = []
    substr = "======"
    with open("gpt_2_gen_texts.txt", 'r') as generated_reviews:
        for line in generated_reviews:
            #append all lines that are not equal signs
            if substr not in line:
                #remove newline token with [:-1]
                review_list.append(line[:-1])
                
    df = pd.DataFrame(review_list, columns=['Review'])
    df['Real'] = 0
    
    df.to_csv("fake_reviews.csv", index=False)
    print("Saved fake_reviews.csv")
    return df

# %%
generate_reviews_path = "gpt_2_gen_texts.txt"
d = create_df_from_txt(generate_reviews_path)
# Out:
# Saved fake_reviews.csv

# %%
real_reviews = pd.read_csv("real_reviews.csv")
fake_reviews = pd.read_csv("fake_reviews.csv")

# %%
real_reviews[:36]
# Out:
#                                                Review  Real
# 0   An appetizer, 2 HUGE dinners, and beer for 35 ...     1
# 1   Mimi's on Shea is under new ownership / manage...     1
# 2   Really cute. Originally from Austin, Texas, th...     1
# 3   Huge servings!! Good food good service.. we'll...     1
# 4   Great food, service, and atmosphere. Great pla...     1
# 5   Consistently great food, I have never had a ba...     1
# 6   This place is amazing. Hand made tortillas and...     1
# 7   Just a great, top-grade place for Indian food....     1
# 8   This place sucks! They forgot to put guac and ...     1
# 9   Fantastic service, Clint's a good man! He take...     1
# 10  I ordered the chicken Thai salad. You get a bu...     1
# 11  Always satisfying.  Don't leave town without t...     1
# 12  No, this wasn't my choice for pizza. Underwhel...     1
# 13  One of the better Chinese restaurants in the U...     1
# 14  Great tasting sandwiches. They put a lot of me...     1
# 15  Great food, try for Sunday brunch, homemade do...     1
# 16  Simply a very good place to get good food on t...     1
# 17  Nice place Mike & Rhonda! I love the special o...     1
# 18  Make sure to register your Friends card online...     1
# 19  Delicious every time! The crust is never mushy...     1
# 20  Great food! Very friendly staffs! Food is trad...     1
# 21  I love Pad Thai but I thought it was just meh ...     1
# 22  Best banh mi in town and friendly service :) a...     1
# 23  Great Sushi and great service.  Emory did a gr...     1
# 24  Must dine here. Amazing food. Menu changes dai...     1
# 25  Great atmosphere, friendly staff, definitely g...     1
# 26  The epitomy of great bbq. I had this catered f...     1
# 27  Forget KFC. End of discussion. \n\nAbout what ...     1
# 28  Wonderful breakfast special, $5.95 steak, eggs...     1
# 29  The service was great and the food was delicio...     1
# 30  My husband and I love this place.. try the win...     1
# 31  Inexpensive and delicious food, and the best m...     1
# 32  It's an expanded gas/convenience mart. Usually...     1
# 33  Best Chinese food I've ever had. Great selecti...     1
# 34  Great bagels! Light and delicious.  Excellent ...     1
# 35  Love the place, super!!!  clean and organized....     1

# %%
#50% real 50% fake is the desired training CSV
print(real_reviews.shape)
print(fake_reviews.shape)
# Out:
# (86550, 2)
# (68663, 2)

# %%
merged_df = pd.concat([fake_reviews, real_reviews], ignore_index=True)

# %%
merged_df
# Out:
#                                                    Review  Real
# 0       Best bbq never had a chicken wings make that s...     0
# 1       I love this place. The best filet on the plane...     0
# 2       This place has the best gelato! One of the bes...     0
# 3       Great spot for sushi at a dinner place. They h...     0
# 4       Small plates, good food, friendly staff who ke...     0
# ...                                                   ...   ...
# 155208  THE BEST CHICKEN! I could drink the sauces the...     1
# 155209  Authentic, yummy subs. Friendly staff. Fresh t...     1
# 155210  Fast and nice service, great lunch special pri...     1
# 155211  I tried the fried chicken it was really good d...     1
# 155212  An all-time favorite for me and my wife.  We g...     1
#
# [155213 rows x 2 columns]
